# %% [markdown]
# [Lesson Video Link](https://course.fast.ai/videos/?lesson=2)
#
# [Lesson resources and updates](https://forums.fast.ai/t/lesson-2-official-resources-and-updates/28630)
#
# [Lesson chat](https://forums.fast.ai/t/lesson-2-chat/28722)
#
# [Further discussion thread](https://forums.fast.ai/t/lesson-2-further-discussion/28706)
#
# Note: This is a mirror of the FastAI Lesson 2 Nb.
# Please thank the amazing team behind fast.ai for creating these, I've merely created a mirror of the same here
# For complete info on the course, visit course.fast.ai

# %% [markdown]
# ### Note: The nb displays an error since the num of files downloaded > limit imposed by kaggle. If you fork and run the nb cell by cell, it should run normally, you will have to uncomment each line of code

# %% [markdown]
# Note: A few lines have been commented out since it causes "Commit Errors" in kaggle (The steps require manual correction of data which causes the kernel to stop running automatically).
# Please uncomment the lines as you spot them

# %% [markdown]
# # Creating your own dataset from Google Images
#
# *by: Francisco Ingham and Jeremy Howard. Inspired by [Adrian Rosebrock](https://www.pyimagesearch.com/2017/12/04/how-to-create-a-deep-learning-dataset-using-google-images/)*

# %%
from fastai import *
from fastai.vision import *

# %% [markdown]
# ## **Get a list of URLs**
#
# **Search and scroll**
#
# Go to Google Images and search for the images you are interested in. The more specific you are in your Google Search, the better the results and the less manual pruning you will have to do.
#
# Scroll down until you've seen all the images you want to download, or until you see a button that says 'Show more results'. All the images you scrolled past are now available to download. To get more, click on the button, and continue scrolling. The maximum number of images Google Images shows is 700.
#
# It is a good idea to put things you want to exclude into the search query, for instance if you are searching for the Eurasian wolf, "canis lupus lupus", it might be a good idea to exclude other variants:
#
# "canis lupus lupus" -dog -arctos -familiaris -baileyi -occidentalis
#
# You can also limit your results to show only photos by clicking on Tools and selecting Photos from the Type dropdown.
#
# **Download into file**
#
# Now you must run some Javascript code in your browser which will save the URLs of all the images you want for you dataset.
#
# Press CtrlShiftJ in Windows/Linux and CmdOptJ in Mac, and a small window the javascript 'Console' will appear. That is where you will paste the JavaScript commands.
#
# You will need to get the urls of each of the images. You can do this by running the following commands:
#
# ```
# urls = Array.from(document.querySelectorAll('.rg_di .rg_meta')).map(el=>JSON.parse(el.textContent).ou);
# window.open('data:text/csv;charset=utf-8,' + escape(urls.join('\n')));
# ```
#
# **Create directory and upload urls file into your server**
#
# Choose an appropriate name for your labeled images. You can run these steps multiple times to grab different labels.

# %% [markdown]
# **Note:** You can download the urls locally and upload them to kaggle using:
#
#
# Here, I have uploaded the urls for
#  - Teddy
#  - Grizzly
#  - Black

# %%
classes = ['teddys','grizzly','black']

# %%
folder = 'black'
file = 'urls_black.txt'

# %%
path = Path('data/bears')
dest = path/folder
dest.mkdir(parents=True, exist_ok=True)

# %%
# !cp ../input/* {path}/

# %%
download_images(path/file, dest, max_pics=200)
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='200' class='' max='200', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [200/200 00:18<00:00]
#     </div>
# Error https://defenders.org/sites/default/files/styles/homepage-feature-2015/public/black-bear_duane-cross.png?itok=zDF-t85w HTTPSConnectionPool(host='defenders.org', port=443): Max retries exceeded with url: /sites/default/files/styles/homepage-feature-2015/public/black-bear_duane-cross.png?itok=zDF-t85w (Caused by SSLError(SSLError("bad handshake: Error([('SSL routines', 'ssl3_get_server_certificate', 'certificate verify failed')],)",),))
# Error https://assets.vancouverisawesome.com/wp-content/uploads/2018/04/09161827/black-bear.jpg HTTPSConnectionPool(host='assets.vancouverisawesome.com', port=443): Max retries exceeded with url: /wp-content/uploads/2018/04/09161827/black-bear.jpg (Caused by NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x7856d39f3eb8>: Failed to establish a new connection: [Errno -2] Name or service not known',))
# Error https://wildsafebc.com/wp-content/uploads/2017/07/blackbear-e1501281687765.jpg HTTPSConnectionPool(host='wildsafebc.com', port=443): Max retries exceeded with url: /wp-content/uploads/2017/07/blackbear-e1501281687765.jpg (Caused by SSLError(SSLError("bad handshake: Error([('SSL routines', 'ssl3_get_server_certificate', 'certificate verify failed')],)",),))
# Error https://wdfw.wa.gov/hunting/permits/spring_bear/graphics/3387scr.jpg HTTPSConnectionPool(host='wdfw.wa.gov', port=443): Max retries exceeded with url: /hunting/permits/spring_bear/graphics/3387scr.jpg (Caused by SSLError(SSLError("bad handshake: Error([('SSL routines', 'ssl3_get_server_certificate', 'certificate verify failed')],)",),))
# Error https://www.thewesternstar.com/media/photologue/photos/cache/34445098_1966729183372095_1748466591902728192_n_large.jpg HTTPSConnectionPool(host='www.thewesternstar.com', port=443): Max retries exceeded with url: /media/photologue/photos/cache/34445098_1966729183372095_1748466591902728192_n_large.jpg (Caused by SSLError(SSLError("bad handshake: Error([('SSL routines', 'ssl3_get_server_certificate', 'certificate verify failed')],)",),))
# Error https://media1.fdncms.com/pique/imager/u/zoom/7910322/news_environment1-1-8bdfc9b45c87de90.jpg HTTPSConnectionPool(host='www.pique.com', port=443): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x7856d3a05c88>: Failed to establish a new connection: [Errno -2] Name or service not known',))
# Error https://cdn.player.one/sites/player.one/files/styles/full_large/public/2015/03/20/black-bear-backcountry-movieh_1.jpg HTTPSConnectionPool(host='cdn.player.one', port=443): Max retries exceeded with url: /sites/player.one/files/styles/full_large/public/2015/03/20/black-bear-backcountry-movieh_1.jpg (Caused by SSLError(SSLError("bad handshake: Error([('SSL routines', 'ssl3_get_server_certificate', 'certificate verify failed')],)",),))
# Error https://media.treehugger.com/assets/images/2011/10/family-of-six-black-bears-caught-on-film.jpg HTTPSConnectionPool(host='media.treehugger.com', port=443): Max retries exceeded with url: /assets/images/2011/10/family-of-six-black-bears-caught-on-film.jpg (Caused by NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x7856d39f3b38>: Failed to establish a new connection: [Errno -2] Name or service not known',))
# Error https://www.coloradocountrylife.coop/wp-content/uploads/2017/09/Feature-2-1.jpg HTTPSConnectionPool(host='www.coloradocountrylife.coop', port=443): Max retries exceeded with url: /wp-content/uploads/2017/09/Feature-2-1.jpg (Caused by SSLError(SSLError("bad handshake: Error([('SSL routines', 'ssl3_get_server_certificate', 'certificate verify failed')],)",),))
# Error https://n7jmr7muhj-flywheel.netdna-ssl.com/wp-content/uploads/2018/02/National-Black-Bear-Day-First-Saturday-in-June-1024x512.jpg HTTPSConnectionPool(host='n7jmr7muhj-flywheel.netdna-ssl.com', port=443): Max retries exceeded with url: /wp-content/uploads/2018/02/National-Black-Bear-Day-First-Saturday-in-June-1024x512.jpg (Caused by NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x7856d3a68ef0>: Failed to establish a new connection: [Errno -2] Name or service not known',))
# Error https://www.cornwallseawaynews.com/content/dam/tc/cornwall-seaway-news/images/2015/6/24/black-bear-2897117.jpg HTTPSConnectionPool(host='www.cornwallseawaynews.com', port=443): Max retries exceeded with url: /content/dam/tc/cornwall-seaway-news/images/2015/6/24/black-bear-2897117.jpg (Caused by SSLError(SSLError("bad handshake: Error([('SSL routines', 'ssl3_get_server_certificate', 'certificate verify failed')],)",),))
# Error https://www.thevintagenews.com/wp-content/uploads/2018/03/c3f9u2ca.jpg HTTPSConnectionPool(host='www.thevintagenews.com', port=443): Max retries exceeded with url: /wp-content/uploads/2018/03/c3f9u2ca.jpg (Caused by SSLError(SSLError("bad handshake: Error([('SSL routines', 'ssl3_get_server_certificate', 'certificate verify failed')],)",),))
# Error https://www.americanhunter.org/media/1994927/donjones_black-bear04084d.gif HTTPSConnectionPool(host='www.americanhunter.org', port=443): Max retries exceeded with url: /media/1994927/donjones_black-bear04084d.gif (Caused by SSLError(SSLError("bad handshake: Error([('SSL routines', 'ssl3_get_server_certificate', 'certificate verify failed')],)",),))
# Error https://www.crozetgazette.com/wp-content/uploads/2018/06/iStock-153562011.jpg HTTPSConnectionPool(host='www.crozetgazette.com', port=443): Max retries exceeded with url: /wp-content/uploads/2018/06/iStock-153562011.jpg (Caused by SSLError(SSLError("bad handshake: Error([('SSL routines', 'ssl3_get_server_certificate', 'certificate verify failed')],)",),))
# Error https://www.massaudubon.org/var/ezdemo_site/storage/images/media/departments/lww/mammals/black-bear-c-karen-karlberg/196541-1-eng-US/black-bear-c-karen-karlberg_large_portrait.jpg HTTPSConnectionPool(host='www.massaudubon.org', port=443): Max retries exceeded with url: /var/ezdemo_site/storage/images/media/departments/lww/mammals/black-bear-c-karen-karlberg/196541-1-eng-US/black-bear-c-karen-karlberg_large_portrait.jpg (Caused by SSLError(SSLError("bad handshake: Error([('SSL routines', 'ssl3_get_server_certificate', 'certificate verify failed')],)",),))
# Error https://img-realtree.com/sites/default/files/styles/site_large/public/content/inserts/realtree-bear-hunting-imagesonthewildside-blackbear.jpg?itok=ItV2_hr- HTTPSConnectionPool(host='img-realtree.com', port=443): Max retries exceeded with url: /sites/default/files/styles/site_large/public/content/inserts/realtree-bear-hunting-imagesonthewildside-blackbear.jpg?itok=ItV2_hr- (Caused by NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x7856d39f35c0>: Failed to establish a new connection: [Errno -2] Name or service not known',))
# Error https://media.fox7austin.com/media.fox7austin.com/photo/2016/06/17/black-bear_1466191202678_1458869_ver1.0_640_360.jpg HTTPSConnectionPool(host='media.fox7austin.com', port=443): Max retries exceeded with url: /media.fox7austin.com/photo/2016/06/17/black-bear_1466191202678_1458869_ver1.0_640_360.jpg (Caused by NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x7856d39f3b70>: Failed to establish a new connection: [Errno -2] Name or service not known',))
# Error https://www.bearbiology.org/wp-content/uploads/2017/12/shutterstock_229367878-1-1024x683.jpg HTTPSConnectionPool(host='www.bearbiology.org', port=443): Max retries exceeded with url: /wp-content/uploads/2017/12/shutterstock_229367878-1-1024x683.jpg (Caused by SSLError(SSLError("bad handshake: Error([('SSL routines', 'ssl3_get_server_certificate', 'certificate verify failed')],)",),))
# Error https://media2.fdncms.com/arktimes/imager/grizlee-blackbear/u/zoom/2696727/alg_wandering_black_bear1_jpg-magnum.jpg HTTPSConnectionPool(host='www.arktimes.com', port=443): Max retries exceeded with url: / (Caused by SSLError(SSLError("bad handshake: Error([('SSL routines', 'ssl3_get_server_certificate', 'certificate verify failed')],)",),))
# Error https://www.alaskawildlife.org/wp-content/uploads/2016/10/AWCC-Muskox-Bears-016.jpg HTTPSConnectionPool(host='www.alaskawildlife.org', port=443): Max retries exceeded with url: /wp-content/uploads/2016/10/AWCC-Muskox-Bears-016.jpg (Caused by SSLError(SSLError("bad handshake: Error([('SSL routines', 'ssl3_get_server_certificate', 'certificate verify failed')],)",),))
# Error https://downeast.com/wp-content/uploads/2014/03/DEE1403Dooryard_Critter1-1024x700.jpg HTTPSConnectionPool(host='downeast.com', port=443): Max retries exceeded with url: /wp-content/uploads/2014/03/DEE1403Dooryard_Critter1-1024x700.jpg (Caused by SSLError(SSLError("bad handshake: Error([('SSL routines', 'ssl3_get_server_certificate', 'certificate verify failed')],)",),))
# Error https://www.ajc.com/rf/image_inline/Wires/w2/USAT_News/2018/02/27/Images/379919002_636553341172182727-0228bear01.jpg HTTPSConnectionPool(host='www.ajc.com', port=443): Max retries exceeded with url: /rf/image_inline/Wires/w2/USAT_News/2018/02/27/Images/379919002_636553341172182727-0228bear01.jpg (Caused by SSLError(SSLError("bad handshake: Error([('SSL routines', 'ssl3_get_server_certificate', 'certificate verify failed')],)",),))
# Error https://defenders.org/sites/default/files/black-bear-mark-bennett-dpc.jpg HTTPSConnectionPool(host='defenders.org', port=443): Max retries exceeded with url: /sites/default/files/black-bear-mark-bennett-dpc.jpg (Caused by SSLError(SSLError("bad handshake: Error([('SSL routines', 'ssl3_get_server_certificate', 'certificate verify failed')],)",),))
# Error https://www.backpacker.com/.image/t_share/MTQ0OTEzOTY2MzY2NDY3NjQ5/bp0316bear_sartore_01800020_750x400.jpg HTTPSConnectionPool(host='www.backpacker.com', port=443): Max retries exceeded with url: /.image/t_share/MTQ0OTEzOTY2MzY2NDY3NjQ5/bp0316bear_sartore_01800020_750x400.jpg (Caused by SSLError(SSLError("bad handshake: Error([('SSL routines', 'ssl3_get_server_certificate', 'certificate verify failed')],)",),))
# Error https://seethewild.org/wp-content/uploads/2017/02/Black_bear_with_salmon.jpg HTTPSConnectionPool(host='seethewild.org', port=443): Max retries exceeded with url: /wp-content/uploads/2017/02/Black_bear_with_salmon.jpg (Caused by SSLError(SSLError("bad handshake: Error([('SSL routines', 'ssl3_get_server_certificate', 'certificate verify failed')],)",),))
# Error https://www.flyingbranch.com/sites/default/files/image-uploads/Black-Bear.jpg HTTPSConnectionPool(host='www.flyingbranch.com', port=443): Max retries exceeded with url: /sites/default/files/image-uploads/Black-Bear.jpg (Caused by SSLError(SSLError("bad handshake: Error([('SSL routines', 'ssl3_get_server_certificate', 'certificate verify failed')],)",),))
# Error https://www.washingtonpost.com/resizer/8oTEoyrrxY092B3yebDUUAdQLdM=/480x0/arc-anglerfish-washpost-prod-washpost.s3.amazonaws.com/public/XK6YBT5GSE2LROLN3FO4WRK5JI.jpg HTTPSConnectionPool(host='www.washingtonpost.com', port=443): Read timed out. (read timeout=4)
# Error http://bearsmartdurango.org/wp-content/uploads/2013/06/100_0642.jpg HTTPSConnectionPool(host='bearsmartdurango.org', port=443): Max retries exceeded with url: /wp-content/uploads/2013/06/100_0642.jpg (Caused by SSLError(SSLError("bad handshake: Error([('SSL routines', 'ssl3_get_server_certificate', 'certificate verify failed')],)",),))
# Error https://cdn-image.travelandleisure.com/sites/default/files/styles/1600x1000/public/1522685410/black-bear-BEAR418.jpg?itok=qmoXuFRx HTTPSConnectionPool(host='cdn-image.travelandleisure.com', port=443): Max retries exceeded with url: /sites/default/files/styles/1600x1000/public/1522685410/black-bear-BEAR418.jpg?itok=qmoXuFRx (Caused by NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x7856d3a05978>: Failed to establish a new connection: [Errno -2] Name or service not known',))
# Error https://www.thecasket.ca/media/photologue/photos/cache/CB-14062018-Black-Bear-SUB_large.jpg HTTPSConnectionPool(host='www.thecasket.ca', port=443): Max retries exceeded with url: /media/photologue/photos/cache/CB-14062018-Black-Bear-SUB_large.jpg (Caused by SSLError(SSLError("bad handshake: Error([('SSL routines', 'ssl3_get_server_certificate', 'certificate verify failed')],)",),))
# Error https://www.calgaryzoo.com/sites/default/files/styles/hero_large/public/2018-05/Bears-Hero-Image.jpg?itok=TK5p4RXI HTTPSConnectionPool(host='www.calgaryzoo.com', port=443): Max retries exceeded with url: /sites/default/files/styles/hero_large/public/2018-05/Bears-Hero-Image.jpg?itok=TK5p4RXI (Caused by SSLError(SSLError("bad handshake: Error([('SSL routines', 'ssl3_get_server_certificate', 'certificate verify failed')],)",),))
# Error https://www.bear.org/website/images/stories/images/images-new/bear_curious.jpg HTTPSConnectionPool(host='www.bear.org', port=443): Max retries exceeded with url: /website/images/stories/images/images-new/bear_curious.jpg (Caused by SSLError(SSLError("bad handshake: Error([('SSL routines', 'ssl3_get_server_certificate', 'certificate verify failed')],)",),))
# Error https://media.mnn.com/assets/images/2015/10/cinnamon-black-bears.jpg.638x0_q80_crop-smart.jpg HTTPSConnectionPool(host='media.mnn.com', port=443): Max retries exceeded with url: /assets/images/2015/10/cinnamon-black-bears.jpg.638x0_q80_crop-smart.jpg (Caused by NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x7856d3a01f98>: Failed to establish a new connection: [Errno -2] Name or service not known',))
# Error https://www.humanesociety.org/sites/default/files/styles/768x326/public/2018/08/black-bear-cubs-436015.jpg?h=7200e980&itok=Fv2yPDlH HTTPSConnectionPool(host='www.humanesociety.org', port=443): Max retries exceeded with url: /sites/default/files/styles/768x326/public/2018/08/black-bear-cubs-436015.jpg?h=7200e980&itok=Fv2yPDlH (Caused by SSLError(SSLError("bad handshake: Error([('SSL routines', 'ssl3_get_server_certificate', 'certificate verify failed')],)",),))
# Error http://www.mikesoutfitting.com/images/BlackBearHunts1-MikesOutfitting.jpg HTTPConnectionPool(host='www.mikesoutfitting.com', port=80): Max retries exceeded with url: /images/BlackBearHunts1-MikesOutfitting.jpg (Caused by ConnectTimeoutError(<urllib3.connection.HTTPConnection object at 0x7856d3a68860>, 'Connection to www.mikesoutfitting.com timed out. (connect timeout=4)'))
# Error http://bearsmartdurango.org/wp-content/uploads/2013/03/cSteelman_5.jpg HTTPSConnectionPool(host='bearsmartdurango.org', port=443): Max retries exceeded with url: /wp-content/uploads/2013/03/cSteelman_5.jpg (Caused by SSLError(SSLError("bad handshake: Error([('SSL routines', 'ssl3_get_server_certificate', 'certificate verify failed')],)",),))
# Error http://aep.alberta.ca/fish-wildlife/wild-species/mammals/bears/images/GFX-Black-Bear-01.jpg HTTPConnectionPool(host='aep.alberta.ca', port=80): Max retries exceeded with url: /fish-wildlife/wild-species/mammals/bears/images/GFX-Black-Bear-01.jpg (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7856d39fb8d0>: Failed to establish a new connection: [Errno -2] Name or service not known',))
# Error https://www.myyosemitepark.com/.image/t_share/MTQ3OTg4NjE5MzcwNTA1Mzcx/bear-amer-black-sitting_680x392.jpg HTTPSConnectionPool(host='www.myyosemitepark.com', port=443): Max retries exceeded with url: /.image/t_share/MTQ3OTg4NjE5MzcwNTA1Mzcx/bear-amer-black-sitting_680x392.jpg (Caused by SSLError(SSLError("bad handshake: Error([('SSL routines', 'ssl3_get_server_certificate', 'certificate verify failed')],)",),))
# Error http://65.110.95.73/wp-content/uploads/2016/10/north-star-outfitting-bearhunts-2.jpg HTTPConnectionPool(host='65.110.95.73', port=80): Max retries exceeded with url: /wp-content/uploads/2016/10/north-star-outfitting-bearhunts-2.jpg (Caused by ConnectTimeoutError(<urllib3.connection.HTTPConnection object at 0x7856d3a10dd8>, 'Connection to 65.110.95.73 timed out. (connect timeout=4)'))
# Error https://static1.squarespace.com/static/5900db44e6f2e13ef4441c28/t/5b10a262562fa7f0109e20c2/1527816841438/Bears.jpg HTTPSConnectionPool(host='images.squarespace-cdn.com', port=443): Max retries exceeded with url: /content/5900db44e6f2e13ef4441c28/1527816830922-EBJ5I5ZN63N7KBP5NCZX/Bears.jpg?format=1000w&content-type=image%2Fjpeg (Caused by SSLError(SSLError("bad handshake: Error([('SSL routines', 'ssl3_get_server_certificate', 'certificate verify failed')],)",),))
# Error https://static1.squarespace.com/static/54c96342e4b0f1b8a5c7a37c/t/58ee58d2ff7c50bddc212099/1492015348592/black-bear-up-close.jpg HTTPSConnectionPool(host='images.squarespace-cdn.com', port=443): Max retries exceeded with url: /content/54c96342e4b0f1b8a5c7a37c/1492015315151-DXQ5F4K4NWFI2HJECPZB/black-bear-up-close.jpg?format=1000w&content-type=image%2Fjpeg (Caused by SSLError(SSLError("bad handshake: Error([('SSL routines', 'ssl3_get_server_certificate', 'certificate verify failed')],)",),))
# Error https://www.romanticasheville.com/sites/default/files/images/basic_page/black-bear-asheville.jpg HTTPSConnectionPool(host='www.romanticasheville.com', port=443): Max retries exceeded with url: /sites/default/files/images/basic_page/black-bear-asheville.jpg (Caused by SSLError(SSLError("bad handshake: Error([('SSL routines', 'ssl3_get_server_certificate', 'certificate verify failed')],)",),))
# Error https://wdfw.wa.gov/living/species/graphics/bear1.jpg HTTPSConnectionPool(host='wdfw.wa.gov', port=443): Max retries exceeded with url: /living/species/graphics/bear1.jpg (Caused by SSLError(SSLError("bad handshake: Error([('SSL routines', 'ssl3_get_server_certificate', 'certificate verify failed')],)",),))
# Error https://friendsofanimals.org/wp-content/uploads/2015/10/Black-Bear-8589.jpg HTTPSConnectionPool(host='friendsofanimals.org', port=443): Max retries exceeded with url: /wp-content/uploads/2015/10/Black-Bear-8589.jpg (Caused by SSLError(SSLError("bad handshake: Error([('SSL routines', 'ssl3_get_server_certificate', 'certificate verify failed')],)",),))
# Error https://images.complex.com/complex/images/c_fill,g_center,w_1200/fl_lossy,pg_1,q_auto/uc5bknusl6ekwyrhtek5/blackbear-lead-1 HTTPSConnectionPool(host='images.complex.com', port=443): Max retries exceeded with url: /complex/images/c_fill,g_center,w_1200/fl_lossy,pg_1,q_auto/uc5bknusl6ekwyrhtek5/blackbear-lead-1 (Caused by SSLError(SSLError("bad handshake: Error([('SSL routines', 'ssl3_get_server_certificate', 'certificate verify failed')],)",),))
# Error https://www.thetimbersresort.com/_assets/images/hunting/black-bear-hunting.jpg HTTPSConnectionPool(host='www.thetimbersresort.com', port=443): Max retries exceeded with url: /_assets/images/hunting/black-bear-hunting.jpg (Caused by SSLError(SSLError("bad handshake: Error([('SSL routines', 'ssl3_get_server_certificate', 'certificate verify failed')],)",),))
# Error https://cdn0.wideopenspaces.com/wp-content/uploads/2017/09/black-bear-ftd-630x339.jpg HTTPSConnectionPool(host='cdn0.wideopenspaces.com', port=443): Read timed out. (read timeout=4)
# Error http://ncpedia.org/sites/default/files/blackbear2.jpg HTTPSConnectionPool(host='ncpedia.org', port=443): Max retries exceeded with url: /sites/default/files/blackbear2.jpg (Caused by SSLError(SSLError("bad handshake: Error([('SSL routines', 'ssl3_get_server_certificate', 'certificate verify failed')],)",),))
# Error https://static1.squarespace.com/static/54c96342e4b0f1b8a5c7a37c/t/58ee5972f7e0abc09cc299eb/1492015512676/black-bear-with-cubs.jpg HTTPSConnectionPool(host='images.squarespace-cdn.com', port=443): Max retries exceeded with url: /content/54c96342e4b0f1b8a5c7a37c/1492015475518-N5ZC012B9CY5KLCWBXHW/black-bear-with-cubs.jpg?format=1000w&content-type=image%2Fjpeg (Caused by SSLError(SSLError("bad handshake: Error([('SSL routines', 'ssl3_get_server_certificate', 'certificate verify failed')],)",),))
# Error https://statesymbolsusa.org/sites/statesymbolsusa.org/files/Blackbear_guyfan_380.jpg HTTPSConnectionPool(host='statesymbolsusa.org', port=443): Max retries exceeded with url: /sites/statesymbolsusa.org/files/Blackbear_guyfan_380.jpg (Caused by SSLError(SSLError("bad handshake: Error([('SSL routines', 'ssl3_get_server_certificate', 'certificate verify failed')],)",),))
# Error https://www.langleyadvance.com/wp-content/uploads/2018/08/13207973_web1_180706-SNM-M-Black-Bear-2.jpg HTTPSConnectionPool(host='www.langleyadvance.com', port=443): Max retries exceeded with url: /wp-content/uploads/2018/08/13207973_web1_180706-SNM-M-Black-Bear-2.jpg (Caused by SSLError(CertificateError("hostname 'www.langleyadvance.com' doesn't match either of '*.wpengine.com', 'wpengine.com'",),))
# Error https://xheimmxl4gfvfghng2jjos4qhb.gcdn.anvato.net/captures/CA6/860/CA68600D422B4C19A424B7F82B091FEA.jpg?Expires=1639891568&KeyName=mcpkey1&Signature=9_uKE8A0s46v9uy2BcErECuEtuk HTTPSConnectionPool(host='xheimmxl4gfvfghng2jjos4qhb.gcdn.anvato.net', port=443): Max retries exceeded with url: /captures/CA6/860/CA68600D422B4C19A424B7F82B091FEA.jpg?Expires=1639891568&KeyName=mcpkey1&Signature=9_uKE8A0s46v9uy2BcErECuEtuk (Caused by NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x7856e3fae518>: Failed to establish a new connection: [Errno -2] Name or service not known',))
# Error https://wgfd.wyo.gov/WGFD/media/images/Wildlife/Large%20Carnivores/Bear%20Wise/BearWise_IDBlack.jpg HTTPSConnectionPool(host='wgfd.wyo.gov', port=443): Max retries exceeded with url: /WGFD/media/images/Wildlife/Large%20Carnivores/Bear%20Wise/BearWise_IDBlack.jpg (Caused by SSLError(SSLError("bad handshake: SysCallError(104, 'ECONNRESET')",),))
# Error https://www.wildlife.ca.gov/portals/0/Images/OCEO/KeepMeWild/kmw-black-bear.jpg HTTPSConnectionPool(host='www.wildlife.ca.gov', port=443): Max retries exceeded with url: /portals/0/Images/OCEO/KeepMeWild/kmw-black-bear.jpg (Caused by ConnectTimeoutError(<urllib3.connection.VerifiedHTTPSConnection object at 0x7856e3fac2b0>, 'Connection to www.wildlife.ca.gov timed out. (connect timeout=4)'))
# Error https://i.pennlive.com/resizer/u2ybrNEEMiZQdM7I2jitIzeAL3g=/600x0/arc-anglerfish-arc2-prod-advancelocal/public/HKI2TVF74JGFDFW3YOOW3ND2XM.jpeg HTTPSConnectionPool(host='i.pennlive.com', port=443): Max retries exceeded with url: /resizer/u2ybrNEEMiZQdM7I2jitIzeAL3g=/600x0/arc-anglerfish-arc2-prod-advancelocal/public/HKI2TVF74JGFDFW3YOOW3ND2XM.jpeg (Caused by SSLError(SSLError("bad handshake: Error([('SSL routines', 'ssl3_get_server_certificate', 'certificate verify failed')],)",),))
# Error https://s.newsweek.com/sites/www.newsweek.com/files/styles/full/public/2018/12/20/black-bear-florida-arrested-abuse.jpg HTTPSConnectionPool(host='d.newsweek.com', port=443): Max retries exceeded with url: /en/full/1267596/black-bear-florida-arrested-abuse.jpg (Caused by SSLError(SSLError("bad handshake: Error([('SSL routines', 'ssl3_get_server_certificate', 'certificate verify failed')],)",),))
# Error https://wildlife.state.nh.us/images/slides/bear-hunt-5.jpg HTTPSConnectionPool(host='wildlife.state.nh.us', port=443): Max retries exceeded with url: /images/slides/bear-hunt-5.jpg (Caused by SSLError(SSLError("bad handshake: Error([('SSL routines', 'ssl3_get_server_certificate', 'certificate verify failed')],)",),))
# Error https://www.bear.org/website/images/stories/images/HWB_800x600/HWB_Slide04_FS_800.jpg HTTPSConnectionPool(host='www.bear.org', port=443): Max retries exceeded with url: /website/images/stories/images/HWB_800x600/HWB_Slide04_FS_800.jpg (Caused by SSLError(SSLError("bad handshake: Error([('SSL routines', 'ssl3_get_server_certificate', 'certificate verify failed')],)",),))
# Error https://www.forestanimalrescue.org/wp-content/uploads/2012/09/Lizzy-bear-e1501804448539.jpg HTTPSConnectionPool(host='www.forestanimalrescue.org', port=443): Max retries exceeded with url: /wp-content/uploads/2012/09/Lizzy-bear-e1501804448539.jpg (Caused by SSLError(SSLError("bad handshake: Error([('SSL routines', 'ssl3_get_server_certificate', 'certificate verify failed')],)",),))
# Error x-raw-image:///08a30e8397a4e0ab7620c2efb00097f48e46778ccc9714c8c32e5dac9a16e3e9 No connection adapters were found for 'x-raw-image:///08a30e8397a4e0ab7620c2efb00097f48e46778ccc9714c8c32e5dac9a16e3e9'
# Error http://www.greater-yellowstone.com/graphics/wildlife/Black-Bear/Black-Bear-23085.jpg HTTPConnectionPool(host='www.greater-yellowstone.com', port=80): Max retries exceeded with url: /graphics/wildlife/Black-Bear/Black-Bear-23085.jpg (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7856d3a08f28>: Failed to establish a new connection: [Errno -2] Name or service not known',))
# Error http://www.greater-yellowstone.com/graphics/wildlife/Black-Bear/Black-Bear-23084.jpg HTTPConnectionPool(host='www.greater-yellowstone.com', port=80): Max retries exceeded with url: /graphics/wildlife/Black-Bear/Black-Bear-23084.jpg (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7856e3fa6dd8>: Failed to establish a new connection: [Errno -2] Name or service not known',))
# Error https://cdn0.wideopenspaces.com/wp-content/uploads/2015/04/bear-121.jpg HTTPSConnectionPool(host='cdn0.wideopenspaces.com', port=443): Read timed out. (read timeout=4)
# Error http://fwp.mt.gov/export/resources/images/education/bearID/BearIdTraining_coverSm.jpg HTTPConnectionPool(host='fwp.mt.gov', port=80): Max retries exceeded with url: /export/resources/images/education/bearID/BearIdTraining_coverSm.jpg (Caused by ConnectTimeoutError(<urllib3.connection.HTTPConnection object at 0x7856d39f4470>, 'Connection to fwp.mt.gov timed out. (connect timeout=4)'))
# Error http://www.archives.state.al.us/emblems/images/blackbear.jpg HTTPConnectionPool(host='www.archives.state.al.us', port=80): Max retries exceeded with url: /emblems/images/blackbear.jpg (Caused by ConnectTimeoutError(<urllib3.connection.HTTPConnection object at 0x7856d3a25b00>, 'Connection to www.archives.state.al.us timed out. (connect timeout=4)'))
# Error https://cdn0.wideopenspaces.com/wp-content/uploads/2015/04/bear-111.jpg HTTPSConnectionPool(host='cdn0.wideopenspaces.com', port=443): Read timed out. (read timeout=4)

# %%
folder = 'teddys'
file = 'urls_teddys.txt'

# %%
path = Path('data/bears')
dest = path/folder
dest.mkdir(parents=True, exist_ok=True)

# %%
download_images(path/file, dest, max_pics=200)
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='200' class='' max='200', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [200/200 00:13<00:00]
#     </div>
# Error http://cdn.shopify.com/s/files/1/0084/9282/products/Harvard-Bear-_Caramel_-min_1024x1024.jpg?v=1500302166 HTTPSConnectionPool(host='cdn.shopify.com', port=443): Max retries exceeded with url: /s/files/1/0084/9282/products/Harvard-Bear-_Caramel_-min_1024x1024.jpg?v=1500302166 (Caused by SSLError(SSLError("bad handshake: Error([('SSL routines', 'ssl3_get_server_certificate', 'certificate verify failed')],)",),))
# Error https://www.archiesonline.com/upload/product/large/Baby_Bear_Teddy_Soft_Toy__89070890042233A_83818476.jpg HTTPSConnectionPool(host='www.archiesonline.com', port=443): Max retries exceeded with url: /upload/product/large/Baby_Bear_Teddy_Soft_Toy__89070890042233A_83818476.jpg (Caused by SSLError(SSLError("bad handshake: Error([('SSL routines', 'ssl3_get_server_certificate', 'certificate verify failed')],)",),))
# Error https://sahnisbakery.in/media/catalog/product/cache/1/image/370x480/9df78eab33525d08d6e5fb8d27136e95/t/e/teddy_and_silk_chocolate.jpg HTTPSConnectionPool(host='sahnisbakery.in', port=443): Max retries exceeded with url: /media/catalog/product/cache/1/image/370x480/9df78eab33525d08d6e5fb8d27136e95/t/e/teddy_and_silk_chocolate.jpg (Caused by SSLError(CertificateError("hostname 'sahnisbakery.in' doesn't match either of 'cethos.ca', 'www.cethos.ca'",),))
# Error https://www.archiesonline.com/upload/product/large/Light_Cream_Cuddly_Teddy_Bear_8907089439672_b1a86335.jpg HTTPSConnectionPool(host='www.archiesonline.com', port=443): Max retries exceeded with url: /upload/product/large/Light_Cream_Cuddly_Teddy_Bear_8907089439672_b1a86335.jpg (Caused by SSLError(SSLError("bad handshake: Error([('SSL routines', 'ssl3_get_server_certificate', 'certificate verify failed')],)",),))
# Error https://www.toycart.com/media/catalog/product/cache/1/image/1100x/9df78eab33525d08d6e5fb8d27136e95/t/c/tca1080000562-1.jpg HTTPSConnectionPool(host='www.toycart.com', port=443): Max retries exceeded with url: /media/catalog/product/cache/1/image/1100x/9df78eab33525d08d6e5fb8d27136e95/t/c/tca1080000562-1.jpg (Caused by SSLError(SSLError("bad handshake: Error([('SSL routines', 'ssl3_get_server_certificate', 'certificate verify failed')],)",),))
# Error https://cdn.apkaabazar.com/wp-content/uploads/2018/05/8-compressed.jpg HTTPSConnectionPool(host='cdn.apkaabazar.com', port=443): Max retries exceeded with url: /wp-content/uploads/2018/05/8-compressed.jpg (Caused by NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x7856d3a13e48>: Failed to establish a new connection: [Errno -2] Name or service not known',))
# Error http://collectionservicesinc.com/108/soorya/wp-content/uploads/2018/06/1301401a.jpg HTTPConnectionPool(host='collectionservicesinc.com', port=80): Max retries exceeded with url: /108/soorya/wp-content/uploads/2018/06/1301401a.jpg (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7856d3a139b0>: Failed to establish a new connection: [Errno -2] Name or service not known',))
# Error https://www.archiesonline.com/upload/product/large/Soft_Blue_Teddy_Bear_For_Him_89070890042239_e8208722.jpg HTTPSConnectionPool(host='www.archiesonline.com', port=443): Max retries exceeded with url: /upload/product/large/Soft_Blue_Teddy_Bear_For_Him_89070890042239_e8208722.jpg (Caused by SSLError(SSLError("bad handshake: Error([('SSL routines', 'ssl3_get_server_certificate', 'certificate verify failed')],)",),))
# Error http://thememyparty.in/theme/img/p/2/0/1/3/2013-thickbox_default.jpg HTTPSConnectionPool(host='thememyparty.in', port=443): Max retries exceeded with url: /theme/img/p/2/0/1/3/2013-thickbox_default.jpg (Caused by SSLError(SSLError("bad handshake: Error([('SSL routines', 'ssl3_get_server_certificate', 'certificate verify failed')],)",),))
# Error https://www.bearessentials.ie/wp-content/uploads/2014/09/Teddy-Bear-Florence-and-Caesar.jpg HTTPSConnectionPool(host='www.bearessentials.ie', port=443): Max retries exceeded with url: /wp-content/uploads/2014/09/Teddy-Bear-Florence-and-Caesar.jpg (Caused by SSLError(SSLError("bad handshake: Error([('SSL routines', 'ssl3_get_server_certificate', 'certificate verify failed')],)",),))
# Error https://www.indiagift.in/cache/2d58c8303513937db210ce96065d941c_w306_h312_sc.jpg HTTPSConnectionPool(host='www.indiagift.in', port=443): Max retries exceeded with url: /cache/2d58c8303513937db210ce96065d941c_w306_h312_sc.jpg (Caused by SSLError(SSLError("bad handshake: Error([('SSL routines', 'ssl3_get_server_certificate', 'certificate verify failed')],)",),))
# Error https://www.onlinedelivery.in/images/uploads/SmallProduct/5320.jpg HTTPSConnectionPool(host='www.onlinedelivery.in', port=443): Max retries exceeded with url: /images/uploads/SmallProduct/5320.jpg (Caused by SSLError(SSLError("bad handshake: Error([('SSL routines', 'ssl3_get_server_certificate', 'certificate verify failed')],)",),))
# Error https://cf1.s3.souqcdn.com/item/2016/02/20/10/13/64/37/item_L_10136437_12441553.jpg HTTPSConnectionPool(host='cf1.s3.souqcdn.com', port=443): Max retries exceeded with url: /item/2016/02/20/10/13/64/37/item_L_10136437_12441553.jpg (Caused by NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x7856d3a68898>: Failed to establish a new connection: [Errno -2] Name or service not known',))
# Error https://sahnisbakery.in/media/catalog/product/cache/1/image/1200x1200/9df78eab33525d08d6e5fb8d27136e95/r/e/red_teddy.jpg HTTPSConnectionPool(host='sahnisbakery.in', port=443): Max retries exceeded with url: /media/catalog/product/cache/1/image/1200x1200/9df78eab33525d08d6e5fb8d27136e95/r/e/red_teddy.jpg (Caused by SSLError(CertificateError("hostname 'sahnisbakery.in' doesn't match either of 'cethos.ca', 'www.cethos.ca'",),))
# Error https://www.archiesonline.com/upload/product/large/Baby_Bear_Teddy_Soft_Toy__89070890042233B_939ff5a8.jpg HTTPSConnectionPool(host='www.archiesonline.com', port=443): Max retries exceeded with url: /upload/product/large/Baby_Bear_Teddy_Soft_Toy__89070890042233B_939ff5a8.jpg (Caused by SSLError(SSLError("bad handshake: Error([('SSL routines', 'ssl3_get_server_certificate', 'certificate verify failed')],)",),))
# Error https://www.todaygiftz.com/wp-content/uploads/2017/08/most_memorable..1_feet_height_teddy_bear_849.jpg HTTPSConnectionPool(host='www.todaygiftz.com', port=443): Max retries exceeded with url: /wp-content/uploads/2017/08/most_memorable..1_feet_height_teddy_bear_849.jpg (Caused by SSLError(SSLError("bad handshake: Error([('SSL routines', 'ssl3_get_server_certificate', 'certificate verify failed')],)",),))
# Error https://www.visitglendale.com/wp-content/uploads/2018/06/teddy-bear-day4.png HTTPSConnectionPool(host='www.visitglendale.com', port=443): Max retries exceeded with url: /wp-content/uploads/2018/06/teddy-bear-day4.png (Caused by SSLError(SSLError("bad handshake: Error([('SSL routines', 'ssl3_get_server_certificate', 'certificate verify failed')],)",),))
# Error https://www.indiagift.in/cache/7ee8926912d28c93cecf13afb04c505d_w306_h312_sc.jpg HTTPSConnectionPool(host='www.indiagift.in', port=443): Max retries exceeded with url: /cache/7ee8926912d28c93cecf13afb04c505d_w306_h312_sc.jpg (Caused by SSLError(SSLError("bad handshake: Error([('SSL routines', 'ssl3_get_server_certificate', 'certificate verify failed')],)",),))
# Error https://www.sayitwithbears.co.uk/wp-content/uploads/2017/02/giant-teddy-bear-harry-honey.jpg HTTPSConnectionPool(host='www.sayitwithbears.co.uk', port=443): Max retries exceeded with url: /wp-content/uploads/2017/02/giant-teddy-bear-harry-honey.jpg (Caused by SSLError(SSLError("bad handshake: Error([('SSL routines', 'ssl3_get_server_certificate', 'certificate verify failed')],)",),))
# Error http://buddyplush.com/wp-content/uploads/2016/07/b4.jpg HTTPConnectionPool(host='buddyplush.com', port=80): Max retries exceeded with url: /wp-content/uploads/2016/07/b4.jpg (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7856d39cc6a0>: Failed to establish a new connection: [Errno -2] Name or service not known',))
# Error https://feenix.co.in/wp-content/uploads/2017/12/pretty-mac-desktop-background-cute-teddy-bear-hd-image-9to5animations-mac-desktop-background.jpg HTTPSConnectionPool(host='feenix.co.in', port=443): Max retries exceeded with url: /wp-content/uploads/2017/12/pretty-mac-desktop-background-cute-teddy-bear-hd-image-9to5animations-mac-desktop-background.jpg (Caused by SSLError(SSLError("bad handshake: Error([('SSL routines', 'ssl3_get_server_certificate', 'certificate verify failed')],)",),))
# Error https://style.giftcart.com/pub/media/catalog/product/cache/c9e0b0ef589f3508e5ba515cde53c5ff/c/m/cm01gbgt2136-0.jpg HTTPSConnectionPool(host='style.giftcart.com', port=443): Max retries exceeded with url: /pub/media/catalog/product/cache/c9e0b0ef589f3508e5ba515cde53c5ff/c/m/cm01gbgt2136-0.jpg (Caused by NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x7856d39cc3c8>: Failed to establish a new connection: [Errno -2] Name or service not known',))
# Error https://www.bluefrogtoys.co.uk/images/stories/virtuemart/product/Flashing%20Puffer%20Teddy%20Bear%20a.jpg HTTPSConnectionPool(host='www.bluefrogtoys.co.uk', port=443): Max retries exceeded with url: /images/stories/virtuemart/product/Flashing%20Puffer%20Teddy%20Bear%20a.jpg (Caused by SSLError(SSLError("bad handshake: Error([('SSL routines', 'ssl3_get_server_certificate', 'certificate verify failed')],)",),))
# Error https://www.indiagift.in/cache/4041b3121477924678bbb849144ed8a8_w306_h312_sc.jpg HTTPSConnectionPool(host='www.indiagift.in', port=443): Max retries exceeded with url: /cache/4041b3121477924678bbb849144ed8a8_w306_h312_sc.jpg (Caused by SSLError(SSLError("bad handshake: Error([('SSL routines', 'ssl3_get_server_certificate', 'certificate verify failed')],)",),))
# Error https://www.jerseyheritage.org/media/Shop%20New%20Images/Teddy%20two%20of%20them.jpg HTTPSConnectionPool(host='www.jerseyheritage.org', port=443): Max retries exceeded with url: /media/Shop%20New%20Images/Teddy%20two%20of%20them.jpg (Caused by SSLError(SSLError("bad handshake: Error([('SSL routines', 'ssl3_get_server_certificate', 'certificate verify failed')],)",),))
# Error https://ninainvalentin.si/wp-content/uploads/sites/5/2017/08/Cute-Teddy-Bear-Brogan.jpg HTTPSConnectionPool(host='ninainvalentin.si', port=443): Max retries exceeded with url: /wp-content/uploads/sites/5/2017/08/Cute-Teddy-Bear-Brogan.jpg (Caused by SSLError(SSLError("bad handshake: Error([('SSL routines', 'ssl3_get_server_certificate', 'certificate verify failed')],)",),))
# Error https://m.indiacakes.com/media/catalog/product/cache/1/image/9df78eab33525d08d6e5fb8d27136e95/n/e/new_12_roses_teddy_bear_and_5_chocolates.jpg HTTPSConnectionPool(host='m.indiacakes.com', port=443): Max retries exceeded with url: /media/catalog/product/cache/1/image/9df78eab33525d08d6e5fb8d27136e95/n/e/new_12_roses_teddy_bear_and_5_chocolates.jpg (Caused by NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x7856d39ccb38>: Failed to establish a new connection: [Errno -2] Name or service not known',))
# Error https://images.pexels.com/photos/33196/still-life-teddy-white-read.jpg?cs=srgb&dl=book-cloth-cute-33196.jpg&fm=jpg HTTPSConnectionPool(host='images.pexels.com', port=443): Max retries exceeded with url: /photos/33196/still-life-teddy-white-read.jpg?cs=srgb&dl=book-cloth-cute-33196.jpg&fm=jpg (Caused by SSLError(SSLError("bad handshake: Error([('SSL routines', 'ssl3_get_server_certificate', 'certificate verify failed')],)",),))
# Error https://ak0.scstatic.net/1/bigimg-cdn1-cont11.sweetcouch.com/152993083548126320-cute-teddy-bear-romantic-partner.jpg HTTPSConnectionPool(host='ak0.scstatic.net', port=443): Max retries exceeded with url: /1/bigimg-cdn1-cont11.sweetcouch.com/152993083548126320-cute-teddy-bear-romantic-partner.jpg (Caused by SSLError(SSLError("bad handshake: Error([('SSL routines', 'ssl3_get_server_certificate', 'certificate verify failed')],)",),))
# Error https://cdn2.theweek.co.uk/sites/theweek/files/styles/16x8_465/public/2018/08/100818-wd-chicken-bear.jpg?itok=pBWsX08o HTTPSConnectionPool(host='cdn2.theweek.co.uk', port=443): Max retries exceeded with url: /sites/theweek/files/styles/16x8_465/public/2018/08/100818-wd-chicken-bear.jpg?itok=pBWsX08o (Caused by NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x7856d3a13978>: Failed to establish a new connection: [Errno -2] Name or service not known',))
# Error http://cdn.shopify.com/s/files/1/2622/2548/products/TS1000-A-Wholesale-Plush_1200x.jpg?v=1519702401 HTTPSConnectionPool(host='cdn.shopify.com', port=443): Max retries exceeded with url: /s/files/1/2622/2548/products/TS1000-A-Wholesale-Plush_1200x.jpg?v=1519702401 (Caused by SSLError(SSLError("bad handshake: Error([('SSL routines', 'ssl3_get_server_certificate', 'certificate verify failed')],)",),))
# Error https://www.barbrastreisandstore.com/media/catalog/product/cache/1/image/9df78eab33525d08d6e5fb8d27136e95/t/e/teddy-bear-front.png HTTPSConnectionPool(host='www.barbrastreisandstore.com', port=443): Max retries exceeded with url: /media/catalog/product/cache/1/image/9df78eab33525d08d6e5fb8d27136e95/t/e/teddy-bear-front.png (Caused by SSLError(SSLError("bad handshake: Error([('SSL routines', 'ssl3_get_server_certificate', 'certificate verify failed')],)",),))
# Error http://cdn.shopify.com/s/files/1/0168/0462/products/Meddy-Teddy-Lotus-Prayer-Pose_grande.png?v=1543129183 HTTPSConnectionPool(host='cdn.shopify.com', port=443): Max retries exceeded with url: /s/files/1/0168/0462/products/Meddy-Teddy-Lotus-Prayer-Pose_grande.png?v=1543129183 (Caused by SSLError(SSLError("bad handshake: Error([('SSL routines', 'ssl3_get_server_certificate', 'certificate verify failed')],)",),))
# Error https://comps.canstockphoto.com/romantic-teddy-bears-stock-image_csp0635676.jpg HTTPSConnectionPool(host='comps.canstockphoto.com', port=443): Max retries exceeded with url: /romantic-teddy-bears-stock-image_csp0635676.jpg (Caused by SSLError(SSLError("bad handshake: Error([('SSL routines', 'ssl3_get_server_certificate', 'certificate verify failed')],)",),))
# Error https://www.toycart.com/media/catalog/product/cache/1/image/1100x/9df78eab33525d08d6e5fb8d27136e95/t/c/tca1080000580-1.jpg HTTPSConnectionPool(host='www.toycart.com', port=443): Max retries exceeded with url: /media/catalog/product/cache/1/image/1100x/9df78eab33525d08d6e5fb8d27136e95/t/c/tca1080000580-1.jpg (Caused by SSLError(SSLError("bad handshake: Error([('SSL routines', 'ssl3_get_server_certificate', 'certificate verify failed')],)",),))
# Error https://www.bearessentials.ie/wp-content/uploads/2016/06/Guardian-Angel-Teddy-Bears.jpg HTTPSConnectionPool(host='www.bearessentials.ie', port=443): Max retries exceeded with url: /wp-content/uploads/2016/06/Guardian-Angel-Teddy-Bears.jpg (Caused by SSLError(SSLError("bad handshake: Error([('SSL routines', 'ssl3_get_server_certificate', 'certificate verify failed')],)",),))
# Error https://images.pexels.com/photos/159080/still-life-teddy-white-read-159080.jpeg?cs=srgb&dl=baby-book-child-159080.jpg&fm=jpg HTTPSConnectionPool(host='images.pexels.com', port=443): Max retries exceeded with url: /photos/159080/still-life-teddy-white-read-159080.jpeg?cs=srgb&dl=baby-book-child-159080.jpg&fm=jpg (Caused by SSLError(SSLError("bad handshake: Error([('SSL routines', 'ssl3_get_server_certificate', 'certificate verify failed')],)",),))
# Error https://pixel.nymag.com/imgs/daily/strategist/2018/01/16/giant-teddy-bears/11.nocrop.w710.h2147483647.2x.jpg HTTPSConnectionPool(host='pixel.nymag.com', port=443): Max retries exceeded with url: /imgs/daily/strategist/2018/01/16/giant-teddy-bears/11.nocrop.w710.h2147483647.2x.jpg (Caused by SSLError(SSLError("bad handshake: Error([('SSL routines', 'ssl3_get_server_certificate', 'certificate verify failed')],)",),))
# Error https://video-images.vice.com/articles/58b44ffee71105606e4e557c/lede/1488214870498-Screen-Shot-2017-02-27-at-120026-PM.png?crop=0.8022xw:1xh;0xw,0xh&resize=1200:* HTTPSConnectionPool(host='video-images.vice.com', port=443): Max retries exceeded with url: /articles/58b44ffee71105606e4e557c/lede/1488214870498-Screen-Shot-2017-02-27-at-120026-PM.png?crop=0.8022xw:1xh;0xw,0xh&resize=1200:* (Caused by SSLError(SSLError("bad handshake: Error([('SSL routines', 'ssl3_get_server_certificate', 'certificate verify failed')],)",),))
# Error https://www.bearessentials.ie/wp-content/uploads/2013/05/Giant-Teddy-Bear.jpg HTTPSConnectionPool(host='www.bearessentials.ie', port=443): Max retries exceeded with url: /wp-content/uploads/2013/05/Giant-Teddy-Bear.jpg (Caused by SSLError(SSLError("bad handshake: Error([('SSL routines', 'ssl3_get_server_certificate', 'certificate verify failed')],)",),))
# Error https://agragifts.com/wp-content/uploads/2018/01/STN037-600x800.jpg HTTPSConnectionPool(host='agragifts.com', port=443): Max retries exceeded with url: /wp-content/uploads/2018/01/STN037-600x800.jpg (Caused by NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x7856d3a682b0>: Failed to establish a new connection: [Errno -2] Name or service not known',))
# Error https://www.bigwishbox.com/wp-content/uploads/2017/02/30-red-roses-with-teddy-bear-11284-m.jpg HTTPSConnectionPool(host='www.bigwishbox.com', port=443): Max retries exceeded with url: /wp-content/uploads/2017/02/30-red-roses-with-teddy-bear-11284-m.jpg (Caused by SSLError(SSLError("bad handshake: Error([('SSL routines', 'ssl3_get_server_certificate', 'certificate verify failed')],)",),))
# Error https://cdn.shopify.com/s/files/1/0660/1419/products/bear-pink-large-01.jpg?v=1470430625 HTTPSConnectionPool(host='cdn.shopify.com', port=443): Max retries exceeded with url: /s/files/1/0660/1419/products/bear-pink-large-01.jpg?v=1470430625 (Caused by SSLError(SSLError("bad handshake: Error([('SSL routines', 'ssl3_get_server_certificate', 'certificate verify failed')],)",),))
# Error https://www.archiesonline.com/upload/product/large/Brown_Soft_Teddy_Bear_Small__89070890042374_9cf2354f.jpg HTTPSConnectionPool(host='www.archiesonline.com', port=443): Max retries exceeded with url: /upload/product/large/Brown_Soft_Teddy_Bear_Small__89070890042374_9cf2354f.jpg (Caused by SSLError(SSLError("bad handshake: Error([('SSL routines', 'ssl3_get_server_certificate', 'certificate verify failed')],)",),))
# Error https://cf5.s3.souqcdn.com/item/2018/01/31/30/42/44/92/item_L_30424492_103516482.jpg HTTPSConnectionPool(host='cf5.s3.souqcdn.com', port=443): Max retries exceeded with url: /item/2018/01/31/30/42/44/92/item_L_30424492_103516482.jpg (Caused by NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x7856d39bb908>: Failed to establish a new connection: [Errno -2] Name or service not known',))
# Error https://assets.jassets.com/w_248,h_338,q_80/assets/images/productImage/2018/3/26/11522007816435-1.jpg HTTPSConnectionPool(host='assets.jassets.com', port=443): Max retries exceeded with url: /w_248,h_338,q_80/assets/images/productImage/2018/3/26/11522007816435-1.jpg (Caused by SSLError(SSLError("bad handshake: Error([('SSL routines', 'SSL23_GET_SERVER_HELLO', 'tlsv1 alert internal error')],)",),))
# Error https://www.onlinedelivery.in/images/uploads/SmallProduct/2848.jpg HTTPSConnectionPool(host='www.onlinedelivery.in', port=443): Max retries exceeded with url: /images/uploads/SmallProduct/2848.jpg (Caused by SSLError(SSLError("bad handshake: Error([('SSL routines', 'ssl3_get_server_certificate', 'certificate verify failed')],)",),))
# Error http://mahilaehaat-rmk.gov.in/wp-content/uploads/2018/02/DSC5141.jpg HTTPConnectionPool(host='mahilaehaat-rmk.gov.in', port=80): Max retries exceeded with url: /wp-content/uploads/2018/02/DSC5141.jpg (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7856d39ccba8>: Failed to establish a new connection: [Errno -2] Name or service not known',))
# Error https://www.ecsite.eu/sites/default/files/bearsxhibit1.jpg HTTPSConnectionPool(host='www.ecsite.eu', port=443): Max retries exceeded with url: /sites/default/files/bearsxhibit1.jpg (Caused by ConnectTimeoutError(<urllib3.connection.VerifiedHTTPSConnection object at 0x7856d39bb5c0>, 'Connection to www.ecsite.eu timed out. (connect timeout=4)'))
# Error https://www.easyflowers.co.in/media/wysiwyg/beautyshop/lovely-and-cute-pink-teddy-bear.jpg HTTPSConnectionPool(host='www.easyflowers.co.in', port=443): Read timed out. (read timeout=4)

# %%
folder = 'grizzly'
file = 'urls_grizzly.txt'

# %%
path = Path('data/bears')
dest = path/folder
dest.mkdir(parents=True, exist_ok=True)

# %%
download_images(path/file, dest, max_pics=200)
# Out:
# Error http://alliswall.com/file/617/1920x1200/16:9/cute-grizzly-bear-wallpaper.jpg HTTPConnectionPool(host='alliswall.com', port=80): Max retries exceeded with url: /file/617/1920x1200/16:9/cute-grizzly-bear-wallpaper.jpg (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7856d39ccb70>: Failed to establish a new connection: [Errno -2] Name or service not known',))
# Error https://defenders.org/sites/default/files/styles/homepage-feature-2015/public/grizzley-bear_jim-chagares.png?itok=WVinRHTJ HTTPSConnectionPool(host='defenders.org', port=443): Max retries exceeded with url: /sites/default/files/styles/homepage-feature-2015/public/grizzley-bear_jim-chagares.png?itok=WVinRHTJ (Caused by SSLError(SSLError("bad handshake: Error([('SSL routines', 'ssl3_get_server_certificate', 'certificate verify failed')],)",),))
# Error https://www.outsideonline.com/sites/default/files/styles/full-page/public/2018/08/09/grizzly-bear-trophy-hunting_h.jpg?itok=nJvPMW6q HTTPSConnectionPool(host='www.outsideonline.com', port=443): Max retries exceeded with url: /sites/default/files/styles/full-page/public/2018/08/09/grizzly-bear-trophy-hunting_h.jpg?itok=nJvPMW6q (Caused by SSLError(SSLError("bad handshake: Error([('SSL routines', 'ssl3_get_server_certificate', 'certificate verify failed')],)",),))
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='200' class='' max='200', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [200/200 00:15<00:00]
#     </div>
# Error https://defenders.org/sites/default/files/styles/large/public/grizzly-bear-harry-bosen-dpc.jpg HTTPSConnectionPool(host='defenders.org', port=443): Max retries exceeded with url: /sites/default/files/styles/large/public/grizzly-bear-harry-bosen-dpc.jpg (Caused by SSLError(SSLError("bad handshake: Error([('SSL routines', 'ssl3_get_server_certificate', 'certificate verify failed')],)",),))
# Error https://animalfactguide.com/wp-content/uploads/2013/01/grizzlybear-2.jpg HTTPSConnectionPool(host='animalfactguide.com', port=443): Max retries exceeded with url: /wp-content/uploads/2013/01/grizzlybear-2.jpg (Caused by SSLError(SSLError("bad handshake: Error([('SSL routines', 'ssl3_get_server_certificate', 'certificate verify failed')],)",),))
# Error https://mountainjournal.org/content/articles/ic_1509058466_780x_false.jpg HTTPSConnectionPool(host='mountainjournal.org', port=443): Max retries exceeded with url: /content/articles/ic_1509058466_780x_false.jpg (Caused by SSLError(SSLError("bad handshake: Error([('SSL routines', 'ssl3_get_server_certificate', 'certificate verify failed')],)",),))
# Error https://earthjustice.org/sites/default/files/styles/image_800x600/public/Mangelsen-3124_0.jpg?itok=rbZLvPdx HTTPSConnectionPool(host='earthjustice.org', port=443): Max retries exceeded with url: /sites/default/files/styles/image_800x600/public/Mangelsen-3124_0.jpg?itok=rbZLvPdx (Caused by SSLError(SSLError("bad handshake: Error([('SSL routines', 'ssl3_get_server_certificate', 'certificate verify failed')],)",),))
# Error https://www.gotscience.org/wp-content/uploads/2015/08/19532120519_0fcf695d7b_k-e1441158706270.jpg HTTPSConnectionPool(host='www.gotscience.org', port=443): Max retries exceeded with url: /wp-content/uploads/2015/08/19532120519_0fcf695d7b_k-e1441158706270.jpg (Caused by SSLError(SSLError("bad handshake: Error([('SSL routines', 'SSL23_GET_SERVER_HELLO', 'tlsv1 alert internal error')],)",),))
# Error https://www.fieldandstream.com/sites/fieldandstream.com/files/styles/1000_1x_/public/images/2018/10/grizzly-bear-showing-teeth.jpg?itok=Ze9_mZt6&fc=50,50 HTTPSConnectionPool(host='www.fieldandstream.com', port=443): Max retries exceeded with url: /sites/fieldandstream.com/files/styles/1000_1x_/public/images/2018/10/grizzly-bear-showing-teeth.jpg?itok=Ze9_mZt6&fc=50,50 (Caused by SSLError(SSLError("bad handshake: Error([('SSL routines', 'ssl3_get_server_certificate', 'certificate verify failed')],)",),))
# Error https://media.npr.org/assets/img/2018/05/10/gettyimages-51098914_wide-21fc32f2065f945f86a254b878dbfccf89beae22-s800-c85.jpg HTTPSConnectionPool(host='media.npr.org', port=443): Max retries exceeded with url: /assets/img/2018/05/10/gettyimages-51098914_wide-21fc32f2065f945f86a254b878dbfccf89beae22-s800-c85.jpg (Caused by SSLError(SSLError("bad handshake: Error([('SSL routines', 'ssl3_get_server_certificate', 'certificate verify failed')],)",),))
# Error https://media.mnn.com/assets/images/2015/02/waving-bear.jpg HTTPSConnectionPool(host='media.mnn.com', port=443): Max retries exceeded with url: /assets/images/2015/02/waving-bear.jpg (Caused by NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x7856d39ccba8>: Failed to establish a new connection: [Errno -2] Name or service not known',))
# Error https://s.hswstatic.com/gif/mexican-grizzly-bear-extinct-orig.jpg HTTPSConnectionPool(host='s.hswstatic.com', port=443): Max retries exceeded with url: /gif/mexican-grizzly-bear-extinct-orig.jpg (Caused by NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x7856d39cca90>: Failed to establish a new connection: [Errno -2] Name or service not known',))
# Error https://assets.vancouverisawesome.com/wp-content/uploads/2017/12/18131050/grizzly-bears.jpg HTTPSConnectionPool(host='assets.vancouverisawesome.com', port=443): Max retries exceeded with url: /wp-content/uploads/2017/12/18131050/grizzly-bears.jpg (Caused by NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x7856d39cc518>: Failed to establish a new connection: [Errno -2] Name or service not known',))
# Error https://county17.cdn.ocllc.co/wp-content/uploads/sites/2/2017/10/captured-grizzly-430x305-960x640.jpg HTTPSConnectionPool(host='county17.cdn.ocllc.co', port=443): Max retries exceeded with url: /wp-content/uploads/sites/2/2017/10/captured-grizzly-430x305-960x640.jpg (Caused by NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x7856d39ccb38>: Failed to establish a new connection: [Errno -2] Name or service not known',))
# Error https://cdn-04.independent.ie/life/travel/article36325343.ece/8b61c/AUTOCROP/w620/grizzlybear.jpg HTTPSConnectionPool(host='cdn-04.independent.ie', port=443): Max retries exceeded with url: /life/travel/article36325343.ece/8b61c/AUTOCROP/w620/grizzlybear.jpg (Caused by NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x7856d39ccba8>: Failed to establish a new connection: [Errno -2] Name or service not known',))
# Error https://grizzlycanada.com/wp-content/uploads/2012/09/MG_6929.jpg HTTPSConnectionPool(host='grizzlycanada.com', port=443): Max retries exceeded with url: /wp-content/uploads/2012/09/MG_6929.jpg (Caused by SSLError(SSLError("bad handshake: Error([('SSL routines', 'ssl3_get_server_certificate', 'certificate verify failed')],)",),))
# Error https://static1.squarespace.com/static/52703aebe4b079ec23e10fa2/t/5845bb7646c3c48e3ffbcfbf/1480964997692/First+Light.+%2872%29.jpg HTTPSConnectionPool(host='images.squarespace-cdn.com', port=443): Max retries exceeded with url: /content/52703aebe4b079ec23e10fa2/1480964993734-P43PLB20RTLI23ZXM8KF/First+Light.+%2872%29.jpg?format=1000w&content-type=image%2Fjpeg (Caused by SSLError(SSLError("bad handshake: Error([('SSL routines', 'ssl3_get_server_certificate', 'certificate verify failed')],)",),))
# Error http://www.takepart.com/sites/default/files/styles/large/public/114348309.jpg HTTPSConnectionPool(host='participant.com', port=443): Max retries exceeded with url: /sites/default/files/styles/large/public/114348309.jpg (Caused by SSLError(SSLError("bad handshake: Error([('SSL routines', 'ssl3_get_server_certificate', 'certificate verify failed')],)",),))
# Error https://www.yellowstonepark.com/.image/t_share/MTQ3MzIwMDY4NzkzNjQwMzk4/bear-grizzly-flowers-light_dp_680.jpg HTTPSConnectionPool(host='www.yellowstonepark.com', port=443): Max retries exceeded with url: /.image/t_share/MTQ3MzIwMDY4NzkzNjQwMzk4/bear-grizzly-flowers-light_dp_680.jpg (Caused by SSLError(SSLError("bad handshake: Error([('SSL routines', 'ssl3_get_server_certificate', 'certificate verify failed')],)",),))
# Error https://img.thedailybeast.com/image/upload/c_crop,d_placeholder_euli9k,h_1439,w_2560,x_0,y_0/dpr_2.0/c_limit,w_740/fl_lossy,q_auto/v1492194004/articles/2014/11/23/what-it-takes-to-kill-a-grizzly-bear/141121-peacock-bears-tease_xt4z9w HTTPSConnectionPool(host='img.thedailybeast.com', port=443): Max retries exceeded with url: /image/upload/c_crop,d_placeholder_euli9k,h_1439,w_2560,x_0,y_0/dpr_2.0/c_limit,w_740/fl_lossy,q_auto/v1492194004/articles/2014/11/23/what-it-takes-to-kill-a-grizzly-bear/141121-peacock-bears-tease_xt4z9w (Caused by SSLError(SSLError("bad handshake: Error([('SSL routines', 'ssl3_get_server_certificate', 'certificate verify failed')],)",),))
# Error https://media.npr.org/assets/img/2018/08/29/ap_18221700583150_wide-8485a73a449b2b371197afbde92558300f8cc90b-s800-c85.jpg HTTPSConnectionPool(host='media.npr.org', port=443): Max retries exceeded with url: /assets/img/2018/08/29/ap_18221700583150_wide-8485a73a449b2b371197afbde92558300f8cc90b-s800-c85.jpg (Caused by SSLError(SSLError("bad handshake: Error([('SSL routines', 'ssl3_get_server_certificate', 'certificate verify failed')],)",),))
# Error https://www.outdoorlife.com/sites/outdoorlife.com/files/styles/2000_1x_/public/images/2018/06/grizzly-bear-in-yellowstone-national-park.jpg?itok=ZzqIHP7Z&fc=40,45 HTTPSConnectionPool(host='www.outdoorlife.com', port=443): Max retries exceeded with url: /sites/outdoorlife.com/files/styles/2000_1x_/public/images/2018/06/grizzly-bear-in-yellowstone-national-park.jpg?itok=ZzqIHP7Z&fc=40,45 (Caused by SSLError(SSLError("bad handshake: Error([('SSL routines', 'ssl3_get_server_certificate', 'certificate verify failed')],)",),))
# Error https://icdn2.themanual.com/image/themanual/grizzly-bear-attacking-fish.jpg HTTPSConnectionPool(host='icdn2.themanual.com', port=443): Max retries exceeded with url: /image/themanual/grizzly-bear-attacking-fish.jpg (Caused by NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x7856d39bb2e8>: Failed to establish a new connection: [Errno -2] Name or service not known',))
# Error https://www.goabc.org/wp-content/uploads/2016/12/news-grizzlybear-management-.jpg HTTPSConnectionPool(host='www.goabc.org', port=443): Max retries exceeded with url: /wp-content/uploads/2016/12/news-grizzlybear-management-.jpg (Caused by SSLError(SSLError("bad handshake: Error([('SSL routines', 'ssl3_get_server_certificate', 'certificate verify failed')],)",),))
# Error https://blog.nwf.org/wp-content/blogs.dir/11/files/2015/12/white-collar_Pat-Roque.jpg HTTPSConnectionPool(host='blog.nwf.org', port=443): Max retries exceeded with url: /wp-content/blogs.dir/11/files/2015/12/white-collar_Pat-Roque.jpg (Caused by SSLError(SSLError("bad handshake: Error([('SSL routines', 'ssl3_get_server_certificate', 'certificate verify failed')],)",),))
# Error https://img.thedailybeast.com/image/upload/c_crop,d_placeholder_euli9k,h_1439,w_2560,x_0,y_0/dpr_2.0/c_limit,w_740/fl_lossy,q_auto/v1492177313/articles/2015/08/22/do-killer-grizzlies-deserve-to-die/150821-peacock-grizzlies-tease_fjonp6 HTTPSConnectionPool(host='img.thedailybeast.com', port=443): Max retries exceeded with url: /image/upload/c_crop,d_placeholder_euli9k,h_1439,w_2560,x_0,y_0/dpr_2.0/c_limit,w_740/fl_lossy,q_auto/v1492177313/articles/2015/08/22/do-killer-grizzlies-deserve-to-die/150821-peacock-grizzlies-tease_fjonp6 (Caused by SSLError(SSLError("bad handshake: Error([('SSL routines', 'ssl3_get_server_certificate', 'certificate verify failed')],)",),))
# Error https://s.hswstatic.com/gif/bear-attack-3.jpg HTTPSConnectionPool(host='s.hswstatic.com', port=443): Max retries exceeded with url: /gif/bear-attack-3.jpg (Caused by NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x7856d3a68828>: Failed to establish a new connection: [Errno -2] Name or service not known',))
# Error https://blog.patagonia.com/wp-content/uploads/2018/04/gnam_s_0089_1600TCL-1404x778-c-default.jpg HTTPSConnectionPool(host='blog.patagonia.com', port=443): Max retries exceeded with url: /wp-content/uploads/2018/04/gnam_s_0089_1600TCL-1404x778-c-default.jpg (Caused by SSLError(CertificateError("hostname 'blog.patagonia.com' doesn't match either of '*.wpengine.com', 'wpengine.com'",),))
# Error https://a57.foxnews.com/a57.foxnews.com/static.foxnews.com/foxnews.com/content/uploads/2018/09/640/320/1862/1048/62af5247-bear3.jpg?ve=1&tl=1?ve=1&tl=1 HTTPSConnectionPool(host='a57.foxnews.com', port=443): Max retries exceeded with url: /a57.foxnews.com/static.foxnews.com/foxnews.com/content/uploads/2018/09/640/320/1862/1048/62af5247-bear3.jpg?ve=1&tl=1?ve=1&tl=1 (Caused by SSLError(SSLError("bad handshake: Error([('SSL routines', 'ssl3_get_server_certificate', 'certificate verify failed')],)",),))
# Error https://www.vitalground.org/wp-content/uploads/2017/09/023-Seasons-of-the-Grizzly_robert_scriba_1600.jpg HTTPSConnectionPool(host='www.vitalground.org', port=443): Max retries exceeded with url: /wp-content/uploads/2017/09/023-Seasons-of-the-Grizzly_robert_scriba_1600.jpg (Caused by SSLError(SSLError("bad handshake: Error([('SSL routines', 'ssl3_get_server_certificate', 'certificate verify failed')],)",),))
# Error https://image.slidesharecdn.com/grizzlybear-100615201215-phpapp01/95/grizzly-bear-1-728.jpg?cb=1276633047 HTTPSConnectionPool(host='image.slidesharecdn.com', port=443): Max retries exceeded with url: /grizzlybear-100615201215-phpapp01/95/grizzly-bear-1-728.jpg?cb=1276633047 (Caused by SSLError(SSLError("bad handshake: Error([('SSL routines', 'ssl3_get_server_certificate', 'certificate verify failed')],)",),))
# Error https://media.mnn.com/assets/images/2017/06/yellowstone-grizzly-bear-family.jpg HTTPSConnectionPool(host='media.mnn.com', port=443): Max retries exceeded with url: /assets/images/2017/06/yellowstone-grizzly-bear-family.jpg (Caused by NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x7856d39bb278>: Failed to establish a new connection: [Errno -2] Name or service not known',))
# Error https://davidsuzuki.org/wp-content/uploads/2017/04/grizzly-bears-alaska-wildlife-sanctuary-whittier.jpg HTTPSConnectionPool(host='davidsuzuki.org', port=443): Max retries exceeded with url: /wp-content/uploads/2017/04/grizzly-bears-alaska-wildlife-sanctuary-whittier.jpg (Caused by SSLError(SSLError("bad handshake: Error([('SSL routines', 'ssl3_get_server_certificate', 'certificate verify failed')],)",),))
# Error https://www.mycoastnow.com/wp-content/uploads/2016/09/grizzly-bear-1.jpg HTTPSConnectionPool(host='www.mycoastnow.com', port=443): Max retries exceeded with url: /wp-content/uploads/2016/09/grizzly-bear-1.jpg (Caused by SSLError(SSLError("bad handshake: Error([('SSL routines', 'ssl3_get_server_certificate', 'certificate verify failed')],)",),))
# Error https://www.calgaryzoo.com/sites/default/files/styles/hero_large/public/2018-08/Grizzly%20Bear%20resting.jpg?itok=3qUk5buq HTTPSConnectionPool(host='www.calgaryzoo.com', port=443): Max retries exceeded with url: /sites/default/files/styles/hero_large/public/2018-08/Grizzly%20Bear%20resting.jpg?itok=3qUk5buq (Caused by SSLError(SSLError("bad handshake: Error([('SSL routines', 'ssl3_get_server_certificate', 'certificate verify failed')],)",),))
# Error https://dingo.care2.com/pictures/causes/3210/3209282.large.jpg HTTPSConnectionPool(host='dingo.care2.com', port=443): Max retries exceeded with url: /pictures/causes/3210/3209282.large.jpg (Caused by SSLError(SSLError("bad handshake: Error([('SSL routines', 'ssl3_get_server_certificate', 'certificate verify failed')],)",),))
# Error https://earthjustice.org/sites/default/files/styles/image_800x600/public/grizzly%20blog%20main_0.jpg?itok=uxruF5AN HTTPSConnectionPool(host='earthjustice.org', port=443): Max retries exceeded with url: /sites/default/files/styles/image_800x600/public/grizzly%20blog%20main_0.jpg?itok=uxruF5AN (Caused by SSLError(SSLError("bad handshake: Error([('SSL routines', 'ssl3_get_server_certificate', 'certificate verify failed')],)",),))
# Error https://www.outdoorlife.com/sites/outdoorlife.com/files/styles/2000_1x_/public/custom-touts/2018/07/grizzly-bear-yellowstone-national-park.jpg?itok=nZEUOtkK&fc=71,58 HTTPSConnectionPool(host='www.outdoorlife.com', port=443): Max retries exceeded with url: /sites/outdoorlife.com/files/styles/2000_1x_/public/custom-touts/2018/07/grizzly-bear-yellowstone-national-park.jpg?itok=nZEUOtkK&fc=71,58 (Caused by SSLError(SSLError("bad handshake: Error([('SSL routines', 'ssl3_get_server_certificate', 'certificate verify failed')],)",),))
# Error https://s.hswstatic.com/gif/bear-attack-2.jpg HTTPSConnectionPool(host='s.hswstatic.com', port=443): Max retries exceeded with url: /gif/bear-attack-2.jpg (Caused by NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x7856d39bb780>: Failed to establish a new connection: [Errno -2] Name or service not known',))
# Error https://statesymbolsusa.org/sites/statesymbolsusa.org/files/primary-images/grizzlybearanimalmammal.jpg HTTPSConnectionPool(host='statesymbolsusa.org', port=443): Max retries exceeded with url: /sites/statesymbolsusa.org/files/primary-images/grizzlybearanimalmammal.jpg (Caused by SSLError(SSLError("bad handshake: Error([('SSL routines', 'ssl3_get_server_certificate', 'certificate verify failed')],)",),))
# Error https://blog.oxforddictionaries.com/wp-content/uploads/bears-1200x330.jpg HTTPSConnectionPool(host='blog.oxforddictionaries.com', port=443): Max retries exceeded with url: /wp-content/uploads/bears-1200x330.jpg (Caused by SSLError(SSLError("bad handshake: Error([('SSL routines', 'ssl3_get_server_certificate', 'certificate verify failed')],)",),))
# Error https://images.unsplash.com/photo-1517431821893-b5fe4092f781?ixlib=rb-1.2.1&ixid=eyJhcHBfaWQiOjEyMDd9&w=1000&q=80 HTTPSConnectionPool(host='images.unsplash.com', port=443): Read timed out. (read timeout=4)
# Error https://www.keepitwild.ca/wp-content/uploads/2014/08/BrianHayGriz1.jpg HTTPSConnectionPool(host='www.keepitwild.ca', port=443): Max retries exceeded with url: /wp-content/uploads/2014/08/BrianHayGriz1.jpg (Caused by SSLError(SSLError("bad handshake: Error([('SSL routines', 'ssl3_get_server_certificate', 'certificate verify failed')],)",),))
# Error https://assets.vancouverisawesome.com/wp-content/uploads/2018/07/08143100/grizzly-bear.jpg HTTPSConnectionPool(host='assets.vancouverisawesome.com', port=443): Max retries exceeded with url: /wp-content/uploads/2018/07/08143100/grizzly-bear.jpg (Caused by NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x7856d39ccf98>: Failed to establish a new connection: [Errno -2] Name or service not known',))
# Error https://www.motherjones.com/wp-content/uploads/cover-photo2.jpg?w=990 HTTPSConnectionPool(host='www.motherjones.com', port=443): Max retries exceeded with url: /wp-content/uploads/cover-photo2.jpg?w=990 (Caused by SSLError(SSLError("bad handshake: Error([('SSL routines', 'ssl3_get_server_certificate', 'certificate verify failed')],)",),))
# Error https://www.backpacker.com/.image/t_share/MTU1ODA1NDcwMDQzNDE2MDA4/bearpic.jpg HTTPSConnectionPool(host='www.backpacker.com', port=443): Max retries exceeded with url: /.image/t_share/MTU1ODA1NDcwMDQzNDE2MDA4/bearpic.jpg (Caused by SSLError(SSLError("bad handshake: Error([('SSL routines', 'ssl3_get_server_certificate', 'certificate verify failed')],)",),))
# Error https://www.bear.org/website/images/stories/images/images-new/large_brown_bear.jpg HTTPSConnectionPool(host='www.bear.org', port=443): Max retries exceeded with url: /website/images/stories/images/images-new/large_brown_bear.jpg (Caused by SSLError(SSLError("bad handshake: Error([('SSL routines', 'ssl3_get_server_certificate', 'certificate verify failed')],)",),))
# Error https://s3.wp.wsu.edu/uploads/sites/1996/2016/07/Grizzly-Grisly.jpg HTTPSConnectionPool(host='s3.wp.wsu.edu', port=443): Max retries exceeded with url: /uploads/sites/1996/2016/07/Grizzly-Grisly.jpg (Caused by SSLError(SSLError("bad handshake: Error([('SSL routines', 'ssl3_get_server_certificate', 'certificate verify failed')],)",),))
# Error https://static1.squarespace.com/static/579924e8e58c62c0252c4d9b/t/57fe9ffee3df287b2fb29e66/1476304902195/group+of+grizzly+bears+walking+down+path HTTPSConnectionPool(host='images.squarespace-cdn.com', port=443): Max retries exceeded with url: /content/579924e8e58c62c0252c4d9b/1476304899017-X4KO9SHMIVZW19G4MDGC/group+of+grizzly+bears+walking+down+path?format=1000w&content-type=image%2Fjpeg (Caused by SSLError(SSLError("bad handshake: Error([('SSL routines', 'ssl3_get_server_certificate', 'certificate verify failed')],)",),))
# Error https://wildsafebc.com/wp-content/uploads/2018/01/wildsafebcPsulzle_18-e1517333945626.jpg HTTPSConnectionPool(host='wildsafebc.com', port=443): Max retries exceeded with url: /wp-content/uploads/2018/01/wildsafebcPsulzle_18-e1517333945626.jpg (Caused by SSLError(SSLError("bad handshake: Error([('SSL routines', 'ssl3_get_server_certificate', 'certificate verify failed')],)",),))
# Error https://statesymbolsusa.org/sites/statesymbolsusa.org/files/styles/large/public/Grizzly-fishing380.jpg?itok=WPPGWGDu HTTPSConnectionPool(host='statesymbolsusa.org', port=443): Max retries exceeded with url: /sites/statesymbolsusa.org/files/styles/large/public/Grizzly-fishing380.jpg?itok=WPPGWGDu (Caused by SSLError(SSLError("bad handshake: Error([('SSL routines', 'ssl3_get_server_certificate', 'certificate verify failed')],)",),))
# Error https://images.glaciermedia.ca/polopoly_fs/1.21960352.1502990567!/fileImage/httpImage/image.jpg_gen/derivatives/landscape_804/grizzly.jpg HTTPSConnectionPool(host='images.glaciermedia.ca', port=443): Max retries exceeded with url: /polopoly_fs/1.21960352.1502990567!/fileImage/httpImage/image.jpg_gen/derivatives/landscape_804/grizzly.jpg (Caused by NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x7856d39bb8d0>: Failed to establish a new connection: [Errno -2] Name or service not known',))
# Error https://www.akronzoo.org/Data/Sites/1/media/GalleryImages/105/WebImages/grizzly-bear-hero-1.jpg HTTPSConnectionPool(host='www.akronzoo.org', port=443): Max retries exceeded with url: /Data/Sites/1/media/GalleryImages/105/WebImages/grizzly-bear-hero-1.jpg (Caused by SSLError(SSLError("bad handshake: Error([('SSL routines', 'ssl3_get_server_certificate', 'certificate verify failed')],)",),))
# Error http://www.takepart.com/sites/default/files/styles/large/public/grizzlybear.jpg HTTPSConnectionPool(host='participant.com', port=443): Max retries exceeded with url: /sites/default/files/styles/large/public/grizzlybear.jpg (Caused by SSLError(SSLError("bad handshake: Error([('SSL routines', 'ssl3_get_server_certificate', 'certificate verify failed')],)",),))
# Error https://www.washingtonpost.com/resizer/S2qpHxfmuc7JUINSZp4pd8_N7m4=/480x0/arc-anglerfish-washpost-prod-washpost.s3.amazonaws.com/public/AUEKO7HTGII6RGOCZ7FG7T3BBQ.jpg HTTPSConnectionPool(host='www.washingtonpost.com', port=443): Read timed out. (read timeout=4)
# Error http://aep.alberta.ca/fish-wildlife/wild-species/mammals/bears/images/GFX-Grizzly-01.jpg HTTPConnectionPool(host='aep.alberta.ca', port=80): Max retries exceeded with url: /fish-wildlife/wild-species/mammals/bears/images/GFX-Grizzly-01.jpg (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7856d39cccc0>: Failed to establish a new connection: [Errno -2] Name or service not known',))
# Error https://friresearch.ca/sites/default/files/styles/fri_search_aspect/public/GBP_2018_03_qarry-banner-Bear-Pic.jpg?itok=1AnJDS9N HTTPSConnectionPool(host='friresearch.ca', port=443): Max retries exceeded with url: /sites/default/files/styles/fri_search_aspect/public/GBP_2018_03_qarry-banner-Bear-Pic.jpg?itok=1AnJDS9N (Caused by SSLError(SSLError("bad handshake: Error([('SSL routines', 'ssl3_get_server_certificate', 'certificate verify failed')],)",),))
# Error http://www.wdam.com/resizer/npAifGOtqkqTU3y-ef5go2Ui710=/1200x600/arc-anglerfish-arc2-prod-raycom.s3.amazonaws.com/public/UQCSUFDIKJFTBJBENCNIZCWMVQ.jpg HTTPSConnectionPool(host='www.wdam.com', port=443): Max retries exceeded with url: /resizer/npAifGOtqkqTU3y-ef5go2Ui710=/1200x600/arc-anglerfish-arc2-prod-raycom.s3.amazonaws.com/public/UQCSUFDIKJFTBJBENCNIZCWMVQ.jpg (Caused by SSLError(SSLError("bad handshake: Error([('SSL routines', 'ssl3_get_server_certificate', 'certificate verify failed')],)",),))
# Error https://www.stlzoo.org/files/2315/3721/2590/Grizzly_Bear_Christopher_Carter_25.jpg HTTPSConnectionPool(host='www.stlzoo.org', port=443): Max retries exceeded with url: /files/2315/3721/2590/Grizzly_Bear_Christopher_Carter_25.jpg (Caused by SSLError(SSLError("bad handshake: Error([('SSL routines', 'ssl3_get_server_certificate', 'certificate verify failed')],)",),))
# Error https://www.yellowstonepark.com/.image/t_share/MTQ3MzIwMDY4NTIyNDUyNDMw/yellowstone-bear-grizzly-bp-reader.jpg HTTPSConnectionPool(host='www.yellowstonepark.com', port=443): Max retries exceeded with url: /.image/t_share/MTQ3MzIwMDY4NTIyNDUyNDMw/yellowstone-bear-grizzly-bp-reader.jpg (Caused by SSLError(SSLError("bad handshake: Error([('SSL routines', 'ssl3_get_server_certificate', 'certificate verify failed')],)",),))
# Error https://www.travelchook.com/wp-content/uploads/2017/12/Grizzly-bear-cub-7.jpg HTTPSConnectionPool(host='www.travelchook.com', port=443): Max retries exceeded with url: /wp-content/uploads/2017/12/Grizzly-bear-cub-7.jpg (Caused by SSLError(SSLError("bad handshake: Error([('SSL routines', 'ssl3_get_server_certificate', 'certificate verify failed')],)",),))
# Error https://www.wildernessenterprises.com/wilderness-wp/wp-content/uploads/2014/08/badge-grizzlybear.jpg HTTPSConnectionPool(host='www.wildernessenterprises.com', port=443): Max retries exceeded with url: /wilderness-wp/wp-content/uploads/2014/08/badge-grizzlybear.jpg (Caused by SSLError(SSLError("bad handshake: Error([('SSL routines', 'ssl3_get_server_certificate', 'certificate verify failed')],)",),))
# Error https://ccms.farmjournal.com/sites/default/files/Grizzly_Bear.jpg HTTPSConnectionPool(host='ccms.farmjournal.com', port=443): Max retries exceeded with url: /sites/default/files/Grizzly_Bear.jpg (Caused by SSLError(SSLError("bad handshake: Error([('SSL routines', 'ssl3_get_server_certificate', 'certificate verify failed')],)",),))
# Error https://www.washingtonpost.com/resizer/rNWQ6oDst_gqJ_khkSXYRtftUz4=/1484x0/arc-anglerfish-washpost-prod-washpost.s3.amazonaws.com/public/Q453GZ66JEZEZFGRDAJEPKT254.png HTTPSConnectionPool(host='www.washingtonpost.com', port=443): Read timed out. (read timeout=4)
# Error https://www.theglobeandmail.com/resizer/z-Nv8zI2yaZOHt3CmXnXYCWchWo=/1200x0/filters:quality(80)/arc-anglerfish-tgam-prod-tgam.s3.amazonaws.com/public/TB6DIWCQCBANVDUBLDKEWEWO6M HTTPSConnectionPool(host='www.theglobeandmail.com', port=443): Read timed out. (read timeout=4)
# Error https://www.washingtonpost.com/pbox.php?url=http://www.washingtonpost.com/news/animalia/wp-content/uploads/sites/56/2016/06/cub1.jpg&w=1484&op=resize&opt=1&filter=antialias&t=20170517 HTTPSConnectionPool(host='www.washingtonpost.com', port=443): Read timed out. (read timeout=4)

# %% [markdown]
# Then we can remove any images that can't be opened:

# %%
 for c in classes:
     print(c)
     verify_images(path/c, delete=True, max_size=500)
# Out:
# teddys
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='150' class='' max='150', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [150/150 00:00<00:00]
#     </div>
# Image data/bears/teddys/00000121.png has 4 instead of 3 channels
# cannot identify image file <_io.BufferedReader name='data/bears/teddys/00000093.jpg'>
# cannot identify image file <_io.BufferedReader name='data/bears/teddys/00000153.jpg'>
# cannot identify image file <_io.BufferedReader name='data/bears/teddys/00000067.jpg'>
# cannot identify image file <_io.BufferedReader name='data/bears/teddys/00000102.png'>
# cannot identify image file <_io.BufferedReader name='data/bears/teddys/00000092.jpg'>
# cannot identify image file <_io.BufferedReader name='data/bears/teddys/00000127.jpg'>
# cannot identify image file <_io.BufferedReader name='data/bears/teddys/00000084.jpg'>
# cannot identify image file <_io.BufferedReader name='data/bears/teddys/00000035.jpeg'>
# cannot identify image file <_io.BufferedReader name='data/bears/teddys/00000101.jpg'>
# cannot identify image file <_io.BufferedReader name='data/bears/teddys/00000156.jpg'>
# cannot identify image file <_io.BufferedReader name='data/bears/teddys/00000123.jpg'>
# cannot identify image file <_io.BufferedReader name='data/bears/teddys/00000040.jpg'>
# cannot identify image file <_io.BufferedReader name='data/bears/teddys/00000048.jpg'>
# cannot identify image file <_io.BufferedReader name='data/bears/teddys/00000107.jpg'>
# cannot identify image file <_io.BufferedReader name='data/bears/teddys/00000009.jpg'>
# cannot identify image file <_io.BufferedReader name='data/bears/teddys/00000135.jpg'>
# cannot identify image file <_io.BufferedReader name='data/bears/teddys/00000169.jpg'>
# cannot identify image file <_io.BufferedReader name='data/bears/teddys/00000047.jpg'>
# cannot identify image file <_io.BufferedReader name='data/bears/teddys/00000126.jpg'>
# cannot identify image file <_io.BufferedReader name='data/bears/teddys/00000152.jpg'>
# cannot identify image file <_io.BufferedReader name='data/bears/teddys/00000014.jpg'>
# Image data/bears/teddys/00000115.jpg has 1 instead of 3 channels
# cannot identify image file <_io.BufferedReader name='data/bears/teddys/00000085.jpg'>
# cannot identify image file <_io.BufferedReader name='data/bears/teddys/00000043.jpg'>
# cannot identify image file <_io.BufferedReader name='data/bears/teddys/00000148.jpeg'>
# cannot identify image file <_io.BufferedReader name='data/bears/teddys/00000113.jpg'>
# cannot identify image file <_io.BufferedReader name='data/bears/teddys/00000017.jpg'>
# cannot identify image file <_io.BufferedReader name='data/bears/teddys/00000179.jpg'>
# cannot identify image file <_io.BufferedReader name='data/bears/teddys/00000173.jpg'>
# cannot identify image file <_io.BufferedReader name='data/bears/teddys/00000182.jpg'>
# cannot identify image file <_io.BufferedReader name='data/bears/teddys/00000118.jpg'>
# cannot identify image file <_io.BufferedReader name='data/bears/teddys/00000162.jpg'>
# cannot identify image file <_io.BufferedReader name='data/bears/teddys/00000178.jpg'>
# Image data/bears/teddys/00000083.gif has 1 instead of 3 channels
# cannot identify image file <_io.BufferedReader name='data/bears/teddys/00000086.jpg'>
# cannot identify image file <_io.BufferedReader name='data/bears/teddys/00000022.jpg'>
# cannot identify image file <_io.BufferedReader name='data/bears/teddys/00000071.jpg'>
# cannot identify image file <_io.BufferedReader name='data/bears/teddys/00000027.jpg'>
# cannot identify image file <_io.BufferedReader name='data/bears/teddys/00000157.jpg'>
# cannot identify image file <_io.BufferedReader name='data/bears/teddys/00000132.jpeg'>
# cannot identify image file <_io.BufferedReader name='data/bears/teddys/00000042.jpg'>
# cannot identify image file <_io.BufferedReader name='data/bears/teddys/00000069.jpg'>
# cannot identify image file <_io.BufferedReader name='data/bears/teddys/00000141.jpg'>
# cannot identify image file <_io.BufferedReader name='data/bears/teddys/00000188.jpg'>
# cannot identify image file <_io.BufferedReader name='data/bears/teddys/00000060.jpeg'>
# grizzly
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='88' class='' max='88', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [88/88 00:00<00:00]
#     </div>
# Image data/bears/grizzly/00000088.gif has 1 instead of 3 channels
# black
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='67' class='' max='67', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [67/67 00:00<00:00]
#     </div>

# %% [markdown]
# ## View data

# %%
 np.random.seed(42)
 data = ImageDataBunch.from_folder(path, train=".", valid_pct=0.2,
         ds_tfms=get_transforms(), size=64, num_workers=0).normalize(imagenet_stats)

# %%
data.classes
# Out:
# ['black', 'grizzly', 'teddys']

# %%
data.show_batch(rows=3, figsize=(3,4))

# %%
learn = create_cnn(data, models.resnet34, metrics=error_rate)
# Out:
# Downloading: "https://download.pytorch.org/models/resnet34-333f7ec4.pth" to /root/.torch/models/resnet34-333f7ec4.pth
# 100%|██████████| 87306240/87306240 [00:00<00:00, 107678963.37it/s]

# %%
learn.fit_one_cycle(4)
# Out:
# Total time: 00:10 <p><table style='width:300px; margin-bottom:10px'>
#   <tr>
#     <th>epoch</th>
#     <th>train_loss</th>
#     <th>valid_loss</th>
#     <th>error_rate</th>
#   </tr>
#   <tr>
#     <th>1</th>
#     <th>1.243989</th>
#     <th>0.824327</th>
#     <th>0.274510</th>
#   </tr>
#   <tr>
#     <th>2</th>
#     <th>0.968566</th>
#     <th>0.461528</th>
#     <th>0.176471</th>
#   </tr>
#   <tr>
#     <th>3</th>
#     <th>0.770852</th>
#     <th>0.320587</th>
#     <th>0.078431</th>
#   </tr>
#   <tr>
#     <th>4</th>
#     <th>0.665224</th>
#     <th>0.307426</th>
#     <th>0.117647</th>
#   </tr>
# </table>

# %%
learn.save('stage-1')

# %%
learn.unfreeze()

# %%
help(learn.unfreeze)
# Out:
# Help on method unfreeze in module fastai.basic_train:
#
# unfreeze() method of fastai.basic_train.Learner instance
#     Unfreeze entire model.

# %%
learn.lr_find()
# Out:
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.

# %%
learn.recorder.plot()

# %%
learn.fit_one_cycle(2, max_lr=slice(1e-4,1e-3))
# Out:
# Total time: 00:05 <p><table style='width:300px; margin-bottom:10px'>
#   <tr>
#     <th>epoch</th>
#     <th>train_loss</th>
#     <th>valid_loss</th>
#     <th>error_rate</th>
#   </tr>
#   <tr>
#     <th>1</th>
#     <th>0.279818</th>
#     <th>0.396063</th>
#     <th>0.137255</th>
#   </tr>
#   <tr>
#     <th>2</th>
#     <th>0.237534</th>
#     <th>0.371074</th>
#     <th>0.137255</th>
#   </tr>
# </table>

# %%
learn.save('stage-2')

# %% [markdown]
# ## Interpretation

# %%
learn.load('stage-2');

# %%
interp = ClassificationInterpretation.from_learner(learn)

# %%
interp.plot_confusion_matrix()

# %% [markdown]
# ## Cleaning Up
#
# Some of our top losses aren't due to bad performance by our model. There are images in our data set that shouldn't be.
#
# Using the `ImageCleaner` widget from `fastai.widgets` we can prune our top losses, removing photos that don't belong.

# %%
from fastai.widgets import *

# %% [markdown]
# First we need to get the file paths from our top_losses. We can do this with `.from_toplosses`. We then feed the top losses indexes and corresponding dataset to `ImageCleaner`.
#
# Notice that the widget will not delete images directly from disk but it will create a new csv file `cleaned.csv` from where you can create a new ImageDataBunch with the corrected labels to continue training your model.

# %% [markdown]
# Note: Please Set the Number of images to a number that you'd like to view:
# ex: ```n_imgs=100```

# %%
ds, idxs = DatasetFormatter().from_toplosses(learn, n_imgs=100)

# %%
ImageCleaner(ds, idxs, path)
# Out:
# HBox(children=(VBox(children=(Image(value=b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x01\x00d\x00d\x00\x00\xff…
# Button(button_style='primary', description='Next Batch', layout=Layout(width='auto'), style=ButtonStyle())

# %% [markdown]
# Flag photos for deletion by clicking 'Delete'. Then click 'Next Batch' to delete flagged photos and keep the rest in that row. ImageCleaner will show you a new row of images until there are no more to show. In this case, the widget will show you images until there are none left from top_losses.ImageCleaner(ds, idxs)
#
# You can also find duplicates in your dataset and delete them! To do this, you need to run .from_similars to get the potential duplicates' ids and then run ImageCleaner with duplicates=True. The API works in a similar way as with misclassified images: just choose the ones you want to delete and click 'Next Batch' until there are no more images left.

# %%
ds, idxs = DatasetFormatter().from_similars(learn)
# Out:
# Getting activations...
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='4' class='' max='4', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [4/4 00:03<00:00]
#     </div>
# Computing similarities...

# %% [markdown]
# Remember to recreate your ImageDataBunch from your cleaned.csv to include the changes you made in your data!

# %% [markdown]
# ## Putting your model in production
# >
# You probably want to use CPU for inference, except at massive scale (and you almost certainly don't need to train in real-time). If you don't have a GPU that happens automatically. You can test your model on CPU like so:

# %%
import fastai
fastai.defaults.device = torch.device('cpu')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-39-c58f83b735fc> in <module>()
#       1 import fastai
# ----> 2 fastai.defaults.device = torch.device('cpu')
#
# AttributeError: module 'fastai' has no attribute 'defaults'

# %%
#img = open_image(path/'black'/'00000021.jpg')
#img

# %%
#classes = ['black', 'grizzly', 'teddys']

# %%
#data2 = ImageDataBunch.single_from_classes(path, classes, tfms=get_transforms(), size=224).normalize(imagenet_stats)

# %%
#learn = create_cnn(data2, models.resnet34).load('stage-2')

# %%
#pred_class,pred_idx,outputs = learn.predict(img)
#pred_class

# %% [markdown]
# So you might create a route something like this ([thanks](https://github.com/simonw/cougar-or-not) to Simon Willison for the structure of this code):
#
# ```
#
# @app.route("/classify-url", methods=["GET"])
# async def classify_url(request):
#     bytes = await get_bytes(request.query_params["url"])
#     img = open_image(BytesIO(bytes))
#     _,_,losses = learner.predict(img)
#     return JSONResponse({
#         "predictions": sorted(
#             zip(cat_learner.data.classes, map(float, losses)),
#             key=lambda p: p[1],
#             reverse=True
#         )
#     })
#
#     ```

# %% [markdown]
# (This [example](https://www.starlette.io/) is for the Starlette web app toolkit.)

# %% [markdown]
# ## Things that can go wrong

# %% [markdown]
# - Most of the time things will train fine with the defaults
# - There's not much you really need to tune (despite what you've heard!)
# - Most likely are
#   - Learning rate
#   - Number of epochs

# %% [markdown]
# ### Learning rate (LR) too low

# %%
#learn = create_cnn(data, models.resnet34, metrics=error_rate)

# %%
#learn.fit_one_cycle(5, max_lr=1e-5)

# %%
#learn.recorder.plot_losses()

# %% [markdown]
# As well as taking a really long time, it's getting too many looks at each image, so may overfit.

# %% [markdown]
# ### Too few epochs

# %%
#learn = create_cnn(data, models.resnet34, metrics=error_rate, pretrained=False)

# %%
#learn.fit_one_cycle(1)

# %% [markdown]
# ### Too many epochs

# %%
# np.random.seed(42)
# data = ImageDataBunch.from_folder(path, train=".", valid_pct=0.9, bs=32, 
#        ds_tfms=get_transforms(do_flip=False, max_rotate=0, max_zoom=1, max_lighting=0, max_warp=0
#                              ),size=224, num_workers=4).normalize(imagenet_stats)

# %%
# learn = create_cnn(data, models.resnet50, metrics=error_rate, ps=0, wd=0)
# learn.unfreeze()

# %%
# learn.fit_one_cycle(40, slice(1e-6,1e-4))
